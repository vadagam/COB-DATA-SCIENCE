# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
train_data=pd.read_html("https://docs.google.com/spreadsheets/d/e/2PACX-1vRTK2NvcndgPX41Czu6Ft2Ho_nE-z50BgTqdzwFW0rsJ2nvyNLe2DoIg1COzUbgw80oaRBjfy5-WtFk/pubhtml?urp=gmail_link")
test_data=pd.read_html("https://docs.google.com/spreadsheets/d/e/2PACX-1vRyvZ7lknwiSghK9aen1SaTEYoN3JS40rrGLpcyrsVZy1tB2T4gn6Y3-cdzPUFCPMmmqREWefW3kl4_/pubhtml?urp=gmail_link")

# %%
print(train_data)
# Out:
# [     Unnamed: 0 Unnamed: 1   Unnamed: 2
# 0             1          x            y
# 1             2         24  21.54945196
# 2             3         50  47.46446305
# 3             4         15  17.21865634
# 4             5         38  36.58639803
# ..          ...        ...          ...
# 696         697         58  58.59500642
# 697         698         93  94.62509374
# 698         699         82  88.60376995
# 699         700         66  63.64868529
# 700         701         97   94.9752655
#
# [701 rows x 3 columns]]

# %%
print(test_data)
# Out:
# [     Unnamed: 0 Unnamed: 1   Unnamed: 2
# 0             1          x            y
# 1             2         77  79.77515201
# 2             3         21  23.17727887
# 3             4         22  25.60926156
# 4             5         20  17.85738813
# ..          ...        ...          ...
# 296         297         71   68.5458879
# 297         298         46  47.33487629
# 298         299         55  54.09063686
# 299         300         62  63.29717058
# 300         301         47  52.45946688
#
# [301 rows x 3 columns]]

# %%
set1=train_data[0]
set1.to_csv('train.csv')
train_data=pd.read_csv('train.csv')
train_data
# Out:
#      Unnamed: 0.1  Unnamed: 0 Unnamed: 1   Unnamed: 2
# 0               0           1          x            y
# 1               1           2         24  21.54945196
# 2               2           3         50  47.46446305
# 3               3           4         15  17.21865634
# 4               4           5         38  36.58639803
# ..            ...         ...        ...          ...
# 696           696         697         58  58.59500642
# 697           697         698         93  94.62509374
# 698           698         699         82  88.60376995
# 699           699         700         66  63.64868529
# 700           700         701         97   94.9752655
#
# [701 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['Unnamed: 0.1'].plot(kind='hist', bins=20, title='Unnamed: 0.1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='Unnamed: 0.1', y='Unnamed: 0', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Unnamed: 0.1']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Unnamed: 0.1'}, axis=1)
#               .sort_values('Unnamed: 0.1', ascending=True))
#   xs = counted['Unnamed: 0.1']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('Unnamed: 0.1', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0.1')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Unnamed: 0']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Unnamed: 0'}, axis=1)
#               .sort_values('Unnamed: 0', ascending=True))
#   xs = counted['Unnamed: 0']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('Unnamed: 0', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['Unnamed: 0.1'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0.1')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
trains=train_data.drop("Unnamed: 0",axis=1)
trains.columns=trains.iloc[0]
train_data=trains.drop(0)
train_data
# Out:
# 0      0   x            y
# 1      1  24  21.54945196
# 2      2  50  47.46446305
# 3      3  15  17.21865634
# 4      4  38  36.58639803
# 5      5  87  87.28898389
# ..   ...  ..          ...
# 696  696  58  58.59500642
# 697  697  93  94.62509374
# 698  698  82  88.60376995
# 699  699  66  63.64868529
# 700  700  97   94.9752655
#
# [700 rows x 3 columns]

# %%
set2=test_data[0]
set2.to_csv('test.csv')
test_data=pd.read_csv('test.csv')
test_data
# Out:
#      Unnamed: 0.1  Unnamed: 0 Unnamed: 1   Unnamed: 2
# 0               0           1          x            y
# 1               1           2         77  79.77515201
# 2               2           3         21  23.17727887
# 3               3           4         22  25.60926156
# 4               4           5         20  17.85738813
# ..            ...         ...        ...          ...
# 296           296         297         71   68.5458879
# 297           297         298         46  47.33487629
# 298           298         299         55  54.09063686
# 299           299         300         62  63.29717058
# 300           300         301         47  52.45946688
#
# [301 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0.1'].plot(kind='hist', bins=20, title='Unnamed: 0.1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Unnamed: 0.1', y='Unnamed: 0', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Unnamed: 0.1']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Unnamed: 0.1'}, axis=1)
#               .sort_values('Unnamed: 0.1', ascending=True))
#   xs = counted['Unnamed: 0.1']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_3.sort_values('Unnamed: 0.1', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0.1')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Unnamed: 0']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Unnamed: 0'}, axis=1)
#               .sort_values('Unnamed: 0', ascending=True))
#   xs = counted['Unnamed: 0']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('Unnamed: 0', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['Unnamed: 0.1'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0.1')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
tests=test_data.drop("Unnamed: 0",axis=1)
tests.columns=tests.iloc[0]
test_data=tests.drop(0)
test_data
# Out:
# 0      0   x            y
# 1      1  77  79.77515201
# 2      2  21  23.17727887
# 3      3  22  25.60926156
# 4      4  20  17.85738813
# 5      5  36  41.84986439
# ..   ...  ..          ...
# 296  296  71   68.5458879
# 297  297  46  47.33487629
# 298  298  55  54.09063686
# 299  299  62  63.29717058
# 300  300  47  52.45946688
#
# [300 rows x 3 columns]

# %%
train_dataset=train_data.dropna(subset=['y'])
train_dataset
# Out:
# 0      0   x            y
# 1      1  24  21.54945196
# 2      2  50  47.46446305
# 3      3  15  17.21865634
# 4      4  38  36.58639803
# 5      5  87  87.28898389
# ..   ...  ..          ...
# 696  696  58  58.59500642
# 697  697  93  94.62509374
# 698  698  82  88.60376995
# 699  699  66  63.64868529
# 700  700  97   94.9752655
#
# [699 rows x 3 columns]

# %%
x_train=train_dataset[['x']].astype(float)
x_test=test_data[['x']].astype(float)
y_train=train_dataset[['y']].astype(float)
y_test=test_data[['x']].astype(float)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
yhat=model.predict(x_test)
yhat
# Out:
# array([[76.94327594],
#        [20.90651855],
#        [21.90717494],
#        [19.90586217],
#        [35.91636428],
#        [14.90258026],
#        [61.93343021],
#        [94.95509081],
#        [19.90586217],
#        [ 4.89601644],
#        [ 3.89536006],
#        [18.90520579],
#        [95.95574719],
#        [61.93343021],
#        [35.91636428],
#        [14.90258026],
#        [64.93539936],
#        [13.90192388],
#        [86.94983976],
#        [68.93802488],
#        [88.95115252],
#        [50.92621001],
#        [88.95115252],
#        [26.91045685],
#        [96.95640358],
#        [57.93080468],
#        [78.9445887 ],
#        [20.90651855],
#        [92.95377805],
#        [26.91045685],
#        [98.95771634],
#        [30.91308237],
#        [32.91439514],
#        [79.94524508],
#        [27.91111323],
#        [46.92358448],
#        [52.92752277],
#        [68.93802488],
#        [27.91111323],
#        [32.91439514],
#        [90.95246528],
#        [70.93933765],
#        [49.92555363],
#        [75.94261956],
#        [ 3.89536006],
#        [36.91702066],
#        [69.93868127],
#        [67.9373685 ],
#        [39.91898981],
#        [34.9157079 ],
#        [93.95443443],
#        [87.95049614],
#        [51.92686639],
#        [30.91308237],
#        [58.93146107],
#        [-0.10726546],
#        [38.91833343],
#        [63.93474297],
#        [68.93802488],
#        [56.9301483 ],
#        [12.9012675 ],
#        [71.93999403],
#        [75.94261956],
#        [60.93277383],
#        [81.94655785],
#        [17.90454941],
#        [40.91964619],
#        [49.92555363],
#        [54.92883554],
#        [12.9012675 ],
#        [45.9229281 ],
#        [12.9012675 ],
#        [78.9445887 ],
#        [52.92752277],
#        [14.90258026],
#        [27.91111323],
#        [80.94590147],
#        [68.93802488],
#        [51.92686639],
#        [83.94787061],
#        [67.9373685 ],
#        [26.91045685],
#        [55.92949192],
#        [47.92424086],
#        [39.91898981],
#        [38.91833343],
#        [81.94655785],
#        [99.95837272],
#        [58.93146107],
#        [42.92095896],
#        [66.93671212],
#        [37.91767705],
#        [62.93408659],
#        [90.95246528],
#        [59.93211745],
#        [13.90192388],
#        [20.90651855],
#        [86.94983976],
#        [72.94065041],
#        [31.91373876],
#        [ 1.8940473 ],
#        [81.94655785],
#        [18.90520579],
#        [73.94130679],
#        [41.92030257],
#        [11.90061112],
#        [ 0.89339092],
#        [89.9518089 ],
#        [88.95115252],
#        [-0.10726546],
#        [40.91964619],
#        [15.90323665],
#        [93.95443443],
#        [96.95640358],
#        [65.93605574],
#        [23.9084877 ],
#        [16.90389303],
#        [89.9518089 ],
#        [12.9012675 ],
#        [-0.10726546],
#        [63.93474297],
#        [95.95574719],
#        [97.95705996],
#        [11.90061112],
#        [40.91964619],
#        [46.92358448],
#        [77.94393232],
#        [19.90586217],
#        [88.95115252],
#        [28.91176961],
#        [63.93474297],
#        [74.94196317],
#        [11.90061112],
#        [24.90914408],
#        [27.91111323],
#        [29.91242599],
#        [64.93539936],
#        [58.93146107],
#        [63.93474297],
#        [52.92752277],
#        [70.93933765],
#        [96.95640358],
#        [72.94065041],
#        [ 8.89864197],
#        [11.90061112],
#        [62.93408659],
#        [98.95771634],
#        [59.93211745],
#        [34.9157079 ],
#        [ 1.8940473 ],
#        [59.93211745],
#        [31.91373876],
#        [93.95443443],
#        [83.94787061],
#        [62.93408659],
#        [21.90717494],
#        [80.94590147],
#        [92.95377805],
#        [32.91439514],
#        [ 6.89732921],
#        [41.92030257],
#        [45.9229281 ],
#        [53.92817916],
#        [15.90323665],
#        [48.92489725],
#        [42.92095896],
#        [94.95509081],
#        [65.93605574],
#        [20.90651855],
#        [34.9157079 ],
#        [79.94524508],
#        [36.91702066],
#        [53.92817916],
#        [55.92949192],
#        [ 0.89339092],
#        [31.91373876],
#        [57.93080468],
#        [31.91373876],
#        [45.9229281 ],
#        [71.93999403],
#        [16.90389303],
#        [96.95640358],
#        [92.95377805],
#        [90.95246528],
#        [36.91702066],
#        [ 3.89536006],
#        [53.92817916],
#        [50.92621001],
#        [26.91045685],
#        [45.9229281 ],
#        [91.95312167],
#        [72.94065041],
#        [76.94327594],
#        [90.95246528],
#        [60.93277383],
#        [98.95771634],
#        [ 3.89536006],
#        [71.93999403],
#        [18.90520579],
#        [56.9301483 ],
#        [77.94393232],
#        [25.90980046],
#        [73.94130679],
#        [89.9518089 ],
#        [65.93605574],
#        [12.9012675 ],
#        [39.91898981],
#        [76.94327594],
#        [66.93671212],
#        [74.94196317],
#        [22.90783132],
#        [44.92227172],
#        [58.93146107],
#        [43.92161534],
#        [22.90783132],
#        [54.92883554],
#        [54.92883554],
#        [94.95509081],
#        [11.90061112],
#        [ 3.89536006],
#        [ 6.89732921],
#        [99.95837272],
#        [47.92424086],
#        [41.92030257],
#        [95.95574719],
#        [38.91833343],
#        [99.95837272],
#        [86.94983976],
#        [13.90192388],
#        [13.90192388],
#        [36.91702066],
#        [ 4.89601644],
#        [87.95049614],
#        [90.95246528],
#        [64.93539936],
#        [73.94130679],
#        [55.92949192],
#        [15.90323665],
#        [ 4.89601644],
#        [27.91111323],
#        [91.95312167],
#        [45.9229281 ],
#        [53.92817916],
#        [38.91833343],
#        [43.92161534],
#        [30.91308237],
#        [67.9373685 ],
#        [85.94918338],
#        [89.9518089 ],
#        [37.91767705],
#        [20.90651855],
#        [94.95509081],
#        [55.92949192],
#        [59.93211745],
#        [64.93539936],
#        [77.94393232],
#        [88.95115252],
#        [ 5.89667283],
#        [66.93671212],
#        [35.91636428],
#        [15.90323665],
#        [99.95837272],
#        [44.92227172],
#        [72.94065041],
#        [56.9301483 ],
#        [19.90586217],
#        [75.94261956],
#        [33.91505152],
#        [54.92883554],
#        [71.93999403],
#        [54.92883554],
#        [ 7.89798559],
#        [55.92949192],
#        [71.93999403],
#        [57.93080468],
#        [ 5.89667283],
#        [95.95574719],
#        [22.90783132],
#        [57.93080468],
#        [22.90783132],
#        [18.90520579],
#        [24.90914408],
#        [63.93474297],
#        [20.90651855],
#        [58.93146107],
#        [18.90520579],
#        [15.90323665],
#        [41.92030257],
#        [42.92095896],
#        [60.93277383],
#        [91.95312167],
#        [10.89995474],
#        [40.91964619],
#        [ 0.89339092],
#        [ 7.89798559],
#        [70.93933765],
#        [45.9229281 ],
#        [54.92883554],
#        [61.93343021],
#        [46.92358448]])

# %%
y_test=y_test.squeeze()
yhat=yhat.squeeze()

# %%
showdata=pd.DataFrame({"Test_value":y_test, "Predicted_value":yhat})
showdata
# Out:
#      Test_value  Predicted_value
# 1          77.0        76.943276
# 2          21.0        20.906519
# 3          22.0        21.907175
# 4          20.0        19.905862
# 5          36.0        35.916364
# ..          ...              ...
# 296        71.0        70.939338
# 297        46.0        45.922928
# 298        55.0        54.928836
# 299        62.0        61.933430
# 300        47.0        46.923584
#
# [300 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# showdata['Test_value'].plot(kind='hist', bins=20, title='Test_value')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# showdata['Predicted_value'].plot(kind='hist', bins=20, title='Predicted_value')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# showdata.plot(kind='scatter', x='Test_value', y='Predicted_value', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# showdata['Test_value'].plot(kind='line', figsize=(8, 4), title='Test_value')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# showdata['Predicted_value'].plot(kind='line', figsize=(8, 4), title='Predicted_value')
# plt.gca().spines[['top', 'right']].set_visible(False)
